# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
archivo = '/content/drive/MyDrive/datos_mc.xlsx'
df = pd.read_excel(archivo, sheet_name='googlenet')
df.describe()
y_g = df['Y']
yp_g = df['Y_PRED']
print(y_g)
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     1.0
# 7     1.0
# 8     1.0
# 9     1.0
# 10    2.0
# 11    2.0
# 12    2.0
# 13    2.0
# 14    2.0
# 15    2.0
# 16    2.0
# 17    2.0
# 18    2.0
# 19    2.0
# 20    3.0
# 21    3.0
# 22    3.0
# 23    3.0
# 24    3.0
# 25    3.0
# 26    3.0
# 27    3.0
# 28    3.0
# 29    3.0
# Name: Y, dtype: float64
